# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Python program to display a bar chart of the popularity of programming Languages.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.bar(programming_languages, popularity, align='center', color='b', alpha=0.9)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 2. Write a Python program to display a horizontal bar chart of the popularity of programming Languages.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.barh(programming_languages, popularity, align='center', color='g', alpha=0.9)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 3. Write a Python program to display a bar chart of the popularity of programming Languages. Use uniform color.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
import matplotlib.pyplot as plt

programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.bar(programming_languages, popularity, align='center', color='cornflowerblue', alpha=0.9)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages',  y=-0.1)

# Get the current axes and Invert the y-axis
ax = plt.gca()
ax.invert_yaxis()
# invert labels
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 4. Write a Python program to display a bar chart of the popularity of programming Languages. Use different color for each bar.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
color = list('rbgbyc')

plt.figure()

plt.bar(programming_languages, popularity, align='center', color=color, alpha=0.9)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 5. Write a Python program to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value).
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
popularity_values = [22200000,17600000,8800000,8000000,7700000,6700000]

plt.figure()
plt.bar(programming_languages, popularity, align='center', color='b', alpha=0.9)


def addlabels(x,y,l):
    for i in range(len(x)):
        plt.text(i,y[i],l[i],ha = 'center')
addlabels(x=programming_languages,y=popularity, l=popularity_values )

plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 6. Write a Python program to display a bar chart of the popularity of programming Languages. Make a blue border to each bar.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
import matplotlib.pyplot as plt

programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.bar(programming_languages, popularity, align='center', color='cornflowerblue', alpha=0.9, edgecolor='b')
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 7. Write a Python program to display a bar chart of the popularity of programming Languages. Specify the position of each bar plot.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
# ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}

programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
bar_position = [1,2,5,8,10,11]
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.bar(bar_position, popularity, align='center', color='b', tick_label=programming_languages)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')


# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 8. Write a Python program to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
# ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}

programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
bar_width = [0.2, 0.4,0.8, 1.1, 0.2, 0.5]

plt.figure()
plt.bar(bar_position, popularity, align='center', color='b', width=bar_width, tick_label=programming_languages)
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')


# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [markdown]
# 9. Write a Python program to display a bar chart of the popularity of programming Languages. Increase bottom margin.
#    Sample data:
#    Programming languages: Java, Python, PHP, JavaScript, C#, C++
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
#    The code snippet gives the output shown in the following screenshot.
#
# ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}

programming_languages= ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.figure()
plt.bar(programming_languages, popularity, align='center', color='cornflowerblue', alpha=0.9, edgecolor='b')
plt.xlabel('Languages')
plt.ylabel('Polularity')
plt.title('popularity of programming Languages')
plt.xticks(rotation=90)

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# Get the current axes and set margin
ax = plt.gca()
ax.set_ymargin(0.1)

plt.show()

# %% [markdown]
# 10. Write a Python program to create a bar plot of scores by group and gender. Use multiple X values on the same chart for men and women.
#     Sample data:
#     Means (men) = (22, 30, 35, 35, 26)
#     Means (women) = (25, 32, 30, 35, 29)
#     The code snippet gives the output shown in the following screenshot.
#
# ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
width=0.25
x_ticks=['G1','G2','G3','G4','G5']
x= np.arange(len(x_ticks))
men_means  = [22, 30, 35, 35, 26]
women_means  = [25, 32, 30, 35, 29]

plt.figure()
plt.bar(x, men_means, align='center', color='g', alpha=0.9, edgecolor='b', width=width)
plt.bar(x+width, women_means, align='center', color='r', alpha=0.9, edgecolor='b', width=width)
plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by Person')

# Get the current axes and Invert the y-axis
#ax = plt.gca()
#ax.set_xticks((x + width)/2, x_ticks)
plt.xticks((x + width)/2, x_ticks)

plt.show()

# %% [markdown]
# 11. Write a Python program to create a bar plot from a DataFrame.
#     Sample data frame:
#     a b c d e
#     2 4,8,5,7,6
#     4 2,3,4,2,6
#     6 4,7,4,7,8
#     8 2,6,4,8,6
#     10 2,4,3,3,2
#     The code snippet gives the output shown in the following screenshot.
#
# ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
df = pd.DataFrame({
  'a': [2, 4, 6, 8, 10],
  'b': [4, 2, 4, 2, 2],
  'c': [8, 3, 7, 6, 4],
  'd': [5, 4, 4, 4, 3],
  'e': [7, 2, 7, 8, 3,],
  'f': [6, 6, 8, 6, 2],
})

plt.figure()
df.plot.bar(color={"a": "blue", "b": "green", "c" :"red", "d" :"cyan","e":"purple", "f": "pink"}, edgecolor='b')

# Get and set margin
ax = plt.gca()
ax.set_ymargin(0.1)

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='black',alpha=0.5)
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue', alpha=0.4)
plt.show()

# %% [markdown]
# 12. Write a Python program to create bar plots with error bars on the same figure.
#     Sample data:
#     Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
#     Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645
#     The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
mean_velocity=[round(i*100,2) for i in [ 0.2474, 0.1235, 0.1737, 0.1824]]
x = [i for i in range(len(mean_velocity))]
standard_deviation=[ round(i*10,2) for i in [0.3314, 0.2278, 0.2836, 0.2645]]
plt.figure()
plt.bar(x, mean_velocity,color='r',width=0.5, yerr=standard_deviation )

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='black',alpha=0.5)
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue', alpha=0.4)
plt.show()

# %% [markdown]
# 13. Write a Python program to create bar plots with error bars on the same figure. Attach a text label above each bar displaying men means (integer value).
#     Sample data:
#     Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
#     Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645
#     The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
mean_velocity=[round(i*100,2) for i in [ 0.2474, 0.1235, 0.1737, 0.1824]]
x = [i for i in range(len(mean_velocity))]
standard_deviation=[ round(i*10,2) for i in [0.3314, 0.2278, 0.2836, 0.2645]]
plt.figure()
plt.bar(x, mean_velocity,color='r',width=0.5, yerr=standard_deviation )

def addlabels(x,y,l):
    for i in range(len(x)):
        plt.text(i,y[i],l[i],ha = 'center')
addlabels(x=x,y=mean_velocity, l=mean_velocity )


plt.show()

# %% [markdown]
# 14. Write a Python program to create a stacked bar plot with error bars.
#     Note: Use bottom to stack the women's bars on top of the men’s bars.
#     Sample data:
#     Means (men) = (22, 30, 35, 35, 26)
#     Means (women) = (25, 32, 30, 35, 29)
#     Men standard deviation = (4, 3, 4, 1, 5)
#     Women standard deviation = (3, 5, 2, 3, 3)
#     The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}

means_men = [22, 30, 35, 35, 26]
means_women = [25, 32, 30, 35, 29]
men_standard_deviation = [4, 3, 4, 1, 5]
women_standard_deviation = [3, 5, 2, 3, 3]
x_ticks = [ 'Group1', 'Group2', 'Group3', 'Group4', 'Group5' ]
x = [i for i in range(len(x_ticks))]

plt.figure()

plt.bar(x_ticks, means_men, align='center', color='r', yerr=men_standard_deviation)
plt.bar(x_ticks, means_women, bottom=means_men, align='center', color='g', yerr=women_standard_deviation)
plt.legend(['Men', "Women"])
plt.xlabel('Groups')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.show()

# %% [markdown]
# 15. Write a Python program to create a horizontal bar chart with differently ordered colors.
#     Note: Use bottom to stack the women's bars on top of the men’s bars.
#     Sample data set:
#     languages = [['Language','Science','Math'], ['Science','Math','Language'], ['Math','Language','Science']]
#     numbers = [{'Language':75, 'Science':88, 'Math':96}, {'Language':71, 'Science':95, 'Math':92}, {'Language':75, 'Science':90, 'Math':89}]
#     The code snippet gives the output shown in the following screenshot.
#
#     ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
num_set = [{'Language':75, 'Science':88, 'Math':96},
           {'Language':71, 'Science':95, 'Math':92},
           {'Language':75, 'Science':90, 'Math':89}]

lan_guage  = [['Language','Science','Math'],
               ['Science','Math','Language'],
               ['Math','Language','Science']]

colors = ["r","g","b"]

names = sorted(num_set[0].keys())
values = np.array([[data[name] for name in order] for data, order in zip(num_set, lan_guage)])

lefts = np.insert(np.cumsum(values, axis=1),0,0, axis=1)[:, :-1]

orders = np.array(lan_guage)
bottoms = np.arange(len(lan_guage))

for name, color in zip(names, colors):
	idx = np.where(orders == name)
	value = values[idx]
	left = lefts[idx]
	plt.bar(left, height=0.8, width=value, bottom=bottoms,	color=color, orientation="horizontal", label=name)
plt.yticks(bottoms+0.4, ["Student-%d" % (t+1) for t in bottoms])
plt.legend(loc="best", bbox_to_anchor=(1.0, 1.00))
plt.subplots_adjust(right=0.75)


# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='black',alpha=0.5)
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue', alpha=0.4)
plt.show()

# %%
# @title { vertical-output:true}
numbers = [{'Language':75, 'Science':88, 'Math':96},
            {'Language':71, 'Science':95, 'Math':92},
            {'Language':75, 'Science':90, 'Math':89}]
index = [f'Studnet-{i}' for i in range(len(numbers))]
plt.figure()
df = pd.DataFrame(numbers,index=index)
df.plot.barh(stacked=True, color=['r','b','g'])
plt.legend(df.columns.tolist())

# Customize the major grid and the minor grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='black',alpha=0.5)
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue', alpha=0.4)
plt.show()

# %% [markdown]
# 16. Write a Python program to create a stack bar plot and add a label to each section.
#     Sample data:
#     people = ('G1','G2','G3','G4','G5','G6','G7','G8')
#     segments = 4
#     *multi-dimensional data*
#
#         data = [
#           [3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 7.1123587, 12.77792868, 3.44773477],
#           [11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 6.79685302, 7.24578743, 3.69371847],
#           [3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 4.63832778, 11.16849999, 8.56883433],
#           [4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 10.97567589, 3.98287652, 8.80552122]
#         ]
#     The code snippet gives the output shown in the following screenshot.
#
#     ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}
data = [
    [3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 7.1123587, 12.77792868, 3.44773477],
    [11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 6.79685302, 7.24578743, 3.69371847],
    [3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 4.63832778, 11.16849999, 8.56883433],
    [4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 10.97567589, 3.98287652, 8.80552122]
]
index = [f'G-{i}' for i in range(len(data))]
color = ['r', 'g', 'm', 'tab:cyan', 'w', 'lightblue', 'y', 'c']
plt.figure()
df = pd.DataFrame(data, index=index)

# Plot the horizontal bar chart
ax = df.plot.barh(stacked=True, color=color, edgecolor='black')
plt.legend(df.columns.tolist())

# Calculate relative percentages
df_total = df.sum(axis=1)
df_rel = pd.DataFrame()
for i in df.index:
    df_rel = pd.concat([df_rel, pd.DataFrame((df.loc[i] / df_total.loc[i] * 100)).T])

df_rel.reset_index(drop=True, inplace=True)
df_rel.columns = df.columns

# Add percentage labels
for i in range(df_rel.shape[0]):  # iterate over rows
    cum_sum = 0  # to track cumulative sum for correct placement of text
    for j in range(df_rel.shape[1]):  # iterate over columns
        percentage = df_rel.iloc[i, j]
        cum_sum += df.iloc[i, j]
        ax.text(cum_sum - df.iloc[i, j] / 2, i, f'{percentage:.1f}%', va='center', ha='center', color='black', fontsize=8)

plt.show()

# %% [markdown]
# 17. Write a Python program to add textures (black and white) to bars and wedges.
#     Note: Use bottom to stack the women's bars on top of the men’s bars.
#     The code snippet gives the output shown in the following screenshot.
#
#   ![image.png](data:image/png;base64,...)

# %%
# @title { vertical-output:true}

means_men = [22, 30, 35, 35, 26]
means_women = [25, 32, 30, 35, 29]
x_ticks = [ 'Group1', 'Group2', 'Group3', 'Group4', 'Group5' ]
x = [i for i in range(len(x_ticks))]

plt.figure()

plt.bar(x_ticks, means_men, align='center',hatch='.', color='white', edgecolor='black', )
plt.bar(x_ticks, means_women, bottom=means_men, align='center', hatch='*', color='white', edgecolor='black', )
plt.legend(['Men', "Women"])
plt.xlabel('Groups')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.show()

# %%
# @title { vertical-output:true}
fig = plt.figure()
patterns = [ "|" , "\\" , "/" , "+" , "-", ".", "*","x", "o", "O" ]

ax = fig.add_subplot(111)
for i in range(len(patterns)):
    ax.bar(i, 3, color='white', edgecolor='black', hatch=patterns[i])

plt.show()
